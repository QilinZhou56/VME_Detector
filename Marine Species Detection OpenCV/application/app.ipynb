# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip  -q  install pipreqs
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 4.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.3 which is incompatible.

# %%
# !pipreqs "/content/drive/Shareddrives/Computer Vision Project/Marine Species Detection OpenCV/application"
# Out:
# INFO: Not scanning for jupyter notebooks.
# WARNING: requirements.txt already exists, use --force to overwrite it

# %%
# Path to your requirements.txt file
requirements_path = "/content/drive/Shareddrives/Computer Vision Project/Marine Species Detection OpenCV/application/requirements.txt"

# Read the contents of the file
with open(requirements_path, "r") as file:
    lines = file.readlines()

# Filter out lines mentioning Pillow except for the one you want to keep
filtered_lines = [line for line in lines if "Pillow" not in line]
filtered_lines.append("Pillow==9.4.0\n")  # Add the version of Pillow you decided to keep

# Add the keras-contrib line
filtered_lines.append("git+https://www.github.com/keras-team/keras-contrib.git\n")
filtered_lines.append("tensorflow-addons\n")
filtered_lines.append("torch\n")
filtered_lines.append("transformers\n")

# Write the modified lines back to the file
with open(requirements_path, "w") as file:
    file.writelines(filtered_lines)

# %%
# !pip -q install --upgrade -r "/content/drive/Shareddrives/Computer Vision Project/Marine Species Detection OpenCV/application/requirements.txt"
# Out:
#   Preparing metadata (setup.py) ... done

# %%
# !npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# updated 1 package in 0.48s

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.201.208.98

# %%
# !streamlit run "/content/drive/Shareddrives/Computer Vision Project/Marine Species Detection OpenCV/application/cv_models.py" & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.201.208.98:8501
#
# npx: installed 22 in 2.762s
# your url is: https://witty-ties-stick.loca.lt
# 2024-05-19 22:04:49.029992: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-19 22:04:49.030109: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-19 22:04:49.034813: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# ...

# %% [markdown]
# # other local server tools

# %%
# !pip install pyngrok
import os
from threading import Thread
from pyngrok import ngrok

# %%
ngrok.set_auth_token('2gLBjHr2pDHRWUabKhXDUzXmEtf_77Nv8T9EeS7j9pYw773KF')

# %%
def run_streamlit():
    # Change the port if 8501 is already in use or if you prefer another port
    os.system('streamlit run /content/drive/Shareddrives/Computer Vision Project/Marine Species Detection OpenCV/application/cv_models.py --server.port 8501')

# %%
# Start a thread to run the Streamlit app
thread = Thread(target=run_streamlit)
thread.start()

# %%
# Open a tunnel to the streamlit port 8501
public_url = ngrok.connect(addr='8501', proto='http', bind_tls=True)
print('Your Streamlit app is live at:', public_url)
# Out:
# Your Streamlit app is live at: NgrokTunnel: "https://4f83-34-122-215-99.ngrok-free.app" -> "http://localhost:8501"

# %%
ngrok.kill()
